# %%
import pandas as pd
import numpy as np
from unicodedata import normalize

table_MN = pd.read_html('https://henryu20201c579.github.io/Proyecto_Ingles/Basic1.html')
table_MN
# Out:
# [   English  Spanish
#  0      NaN      NaN
#  1      NaN      NaN
#  2      NaN      NaN,
#     Questions  Answers
#  0        NaN      NaN
#  1        NaN      NaN
#  2        NaN      NaN,
#     English  Spanish
#  0      NaN      NaN
#  1      NaN      NaN
#  2      NaN      NaN,
#     Questions  Answers
#  0        NaN      NaN
#  1        NaN      NaN
#  2        NaN      NaN,
#     English  Spanish
#  0      NaN      NaN
#  1      NaN      NaN
#  2      NaN      NaN,
#     Questions  Answers
#  0        NaN      NaN
#  1        NaN      NaN
#  2        NaN      NaN,
#     English  Spanish
#  0      NaN      NaN
#  1      NaN      NaN
#  2      NaN      NaN,
#     Questions  Answers
#  0        NaN      NaN
#  1        NaN      NaN
#  2        NaN      NaN,
#               English                Spanish
#  0              gifts                regalos
#  1    important items  articulos importantes
#  2            friends                 amigos
# ...

# %%
import pandas as pd

# Supongamos que 'table_MN' es un DataFrame que contiene las tablas con elementos NaN
# Para eliminar las tablas que tienen elementos NaN, puedes usar dropna

table_MN = pd.read_html('https://henryu20201c579.github.io/Proyecto_Ingles/Basic1.html')

# Recorre cada tabla en 'table_MN' y elimina las que contienen elementos NaN
data = [tabla for tabla in table_MN if not tabla.isna().any().any()]

# tables_sin_nan ahora contiene solo las tablas que no tienen elementos NaN

# for i in range (len(data)):
#     print(data[i])

print(data[0].columns[0])
print(data[0].values[0:10])
# Out:
# English
# [['gifts' 'regalos']
#  ['important items' 'articulos importantes']
#  ['friends' 'amigos']
#  ['photo' 'foto']
#  ['candy' 'dulce']
#  ['books' 'libros']
#  ['keys' 'llaves']
#  ['computer' 'computadora']
#  ['soccer ball' 'balón de futbol']
#  ['cellphone' 'teléfono celular']]
