# %%
import pandas as pd

# Para eliminar las tablas que tienen elementos NaN, puedes usar dropna
table_MN = pd.read_html('https://henryu20201c579.github.io/Proyecto_Ingles/Basic2.html')
# Recorre cada tabla en 'table_MN' y elimina las que contienen elementos NaN
data = [tabla for tabla in table_MN if not tabla.isna().any().any()]

print(data[0].columns[0])
print(data[0].values[0:10])
# Out:
# English
# [['text' 'texto']
#  ['play soccer' 'eat']
#  ['read' 'leer']
#  ['outside' 'afuera']
#  ['gym' 'gimnasio']
#  ['classroom' 'clase']
#  ['cafeteria' 'cafeteria']
#  ['exercising' 'ejercitandose']
#  ['talking on the phone' 'hablando por telefono']
#  ['studying' 'estudiando']]
# [                                           English  \
# 0                                             text
# 1                                      play soccer
# 2                                             read
# 3                                          outside
# 4                                              gym
# 5                                        classroom
# 6                                        cafeteria
# 7                                       exercising
# 8                             talking on the phone
# 9                                         studying
# 10                                 drinking coffee
# 11                                 going to school
# 12                                  doing homework
# 13                                texting a friend
# 14                            talking on the phone
# 15                                         running
# 16                                     working out
# 17                              listening to music
# 18                                    eating pizza
# 19                                   drinking soda
# 20                                        shopping
# 21                                     watching TV
# 22                                        sleeping
# 23              Dan is having lunch in the library
# 24       Sophie is talking on the phone at the gym
# 25  Paolo and John are exercising in the cafeteria
# 26          Melissa is studying for a test outside
#
#                                              Spanish
# 0                                              texto
# 1                                                eat
# 2                                               leer
# 3                                             afuera
# 4                                           gimnasio
# 5                                              clase
# 6                                          cafeteria
# 7                                      ejercitandose
# 8                              hablando por telefono
# 9                                         estudiando
# 10                                      tomando cafe
# 11                                   ir a la escuela
# 12                                    haciendo tarea
# 13                              texteando a un amigo
# 14                           hablando en el telefono
# 15                                         corriendo
# 16                                        entrenando
# 17                                 escuchando musica
# 18                                    comiendo pizza
# 19                                   tomando gaseosa
# 20                                         comprando
# 21                                        mirando tv
# 22                                         durmiendo
# 23              Dan está almorzando en la biblioteca
# 24  Sophie está hablando por telefono en el gimnasio
# 25      Paolo y John hacen ejercicio en la cafetería
# 26     Melissa está estudiando para un examen afuera  ,                                             Questions  \
# 0                           What is Ana doing? (text)
# 1                               What is Lionel doing?
# 2   A: How are you doing today?  B: (your answer) ...
# 3   What activities can you do when you're waiting...
# 4                                  How are you doing?
# 5                                     How's it going?
# 6                                  How are you doing?
# 7                                     How's it going?
# 8                                  How are you doing?
# 9   A: How are you doing?  B: I'm soso A: Really? ...
# 10  A: How are you doing?  B: I'm soso A: Really? ...
# 11                      What are you doing? (cooking)
# 12                    What are you doing? (read book)
# 13                   What are you doing? (clean room)
# 14                     What are you doing? (watch tv)
# 15                    Translate: I can't find my keys
# 16                    Translate: I'm stuck in traffic
# 17                               Translate: I'm tired
# 18                 Translate: I'm waiting for the bus
# 19                   Are you making a cup of tea? (+)
# 20                                 Is it raining? (-)
# 21                       Are we going to the gym? (+)
# 22                        Are they having dinner? (-)
# 23              Is Emilie making a cup of coffee? (+)
# 24               Is Sam taking the bus to school? (-)
# 25                   Is Helen dancing? (-, eat pizza)
#
#                                 Answers
# 0                        She is texting
# 1                  He is playing soccer
# 2          Fine, thanks. How about you?
# 3                             I can __.
# 4                         I'm all right
# 5                              I'm fine
# 6                               I'm ok.
# 7                           I'm not bad
# 8                                 So-so
# 9   I'm waiting for the bus. It's late!
# 10  I'm studying for a test. It's hard!
# 11                          I'm cooking
# 12                   I'm reading a book
# 13                  I'm clening my room
# 14                      I'm watching tv
# 15        No puedo encontrar mis llaves
# 16         Estoy atascado en el trafico
# 17                          I'm cansado
# 18           Estoy esperando por el bus
# 19                            Yes, I am
# 20                         No, it isn't
# 21                          Yes, we are
# 22                      No, they aren't
# 23                          Yes, she is
# 24                         No, he isn't
# 25    No, she isn't. She's eating pizza  ,                                               English  \
# 0                                          Pre-School
# 1                                      Nursery School
# 2                                        Kindergarten
# 3                                      Primary School
# 4                                   Elementary School
# ..                                                ...
# 80                                   I want to travel
# 81                            I'm doing it for my job
# 82                          I'm preparing for an exam
# 83                            I'm majoring in English
# 84  Monica is studying English for fun and for her...
#
#                                               Spanish
# 0                                          preescolar
# 1                                           guarderia
# 2                                     jardin infantil
# 3                                            primaria
# 4                                            primaria
# ..                                                ...
# 80                                      quiero viajar
# 81                             lo hago por mi trabajo
# 82                  me estoy peparando para un examen
# 83                  me estoy especializando en ingles
# 84  Monica esta estudiando ingles por diversion y ...
#
# [85 rows x 2 columns],          English     Spanish
# 0      artichoke   alcachofa
# 1      asparagus  esparragos
# 2        avocado       palta
# 3           beet   remolacha
# 4       broccoli     brocoli
# ..           ...         ...
# 107        sugar      azucar
# 108        toast     tostada
# 109  vinaigrette   vinagreta
# 110      vinegar     vinagre
# 111       yogurt      yogurt
#
# [112 rows x 2 columns]]

# %%
import pandas as pd

# Para eliminar las tablas que tienen elementos NaN, puedes usar dropna
table_MN = pd.read_html('https://henryu20201c579.github.io/Proyecto_Ingles/Basic2.html')

len(table_MN) # 6 unidades * 2 tablas = 12 
# 0, 2, 4, 6, 8, 10 -> English -> Spanish
# 1, 3, 5, 7, 9, 11 -> Questions -> Answers

for i in range(len(table_MN)):
    print(table_MN[i].values[0])
# Out:
# ['text' 'texto']
# ['What is Ana doing? (text)' 'She is texting']
# ['Pre-School' 'preescolar']
# [nan nan]
# ['artichoke' 'alcachofa']
# [nan nan]

# %%
import pandas as pd

# Para eliminar las tablas que tienen elementos NaN, puedes usar dropna
#table_MN = pd.read_html('https://henryu20201c579.github.io/Proyecto_Ingles/Basic2.html')

#MENU
print("What level do you want to study?:", 1, 2)
#level = int(input())
level = 1

print("What unit do you want to study?:", 0, 1, 2, 3, 4, 5)
#unit = int(input())*2 - 2
unit = 8

url = "https://henryu20201c579.github.io/Proyecto_Ingles/BasicX.html"

try: 
    url = url[:55] + str(level) + url[55 + 1:]
    data = pd.read_html(url)
except:
    print("this page was not found")

print(data[unit].columns.values)



for i in range(data[unit].values.__len__()):    
    print("\"", data[unit].values[i][0], " - ", data[unit].values[i][1], "\",", sep="")
# Out:
# What level do you want to study?: 1 2
# What unit do you want to study?: 0 1 2 3 4 5
# ['English' 'Spanish']
# "gifts - regalos",
# "important items - articulos importantes",
# "friends - amigos",
# "photo - foto",
# "candy - dulce",
# "books - libros",
# "keys - llaves",
# "computer - computadora",
# "soccer ball - balón de futbol",
# "cellphone - teléfono celular",
# "ring - anillo",
# "apple - manzana",
# "map - mapa",
# "wallet - billetera",
# "camera - camara",
# "tape measure - cinta métrica",
# "safety kit - botiquín",
# "snacks - aperitivos",
# "lipstick - lápiz labial",
# "bag - bolsa",
# "backpack - mochila",
# "briefcasa - maletín",
# "purse - cartera",
# "gift card - tarjeta de regalo",
# "notebook - cuaderno",
# "pencil case - cartuchera",
# "tablet - tableta",
# "charger - cargador",
# "headphones - audifonos",
# "watch - reloj",
# "sunglasses - lentes de sol",
# "earrings - aretes",
# "water bottle - botella de agua",
# "chewing gum - chicle",
# "make-up - maquillaje",
# "comb - peine",
# "band-aids - curitas",
# "pills - pastillas",
# "toothbrush - cepillo dental",
# "toothpaste - pasta dental",
# "passport - pasaporte",
# "ID card - dni",
# "driver license - licencia de conducir",
# "coin purse - monedero",
# "coins - monedas",
# "bills - billetes",
# "birthday - cumpleaños",
# "wedding - boda",
# "graduation - graduacion",
# "brand - marca",
# "teddy bear - oso de peluche",
# "perfume - perfume",
# "bracelet - pulsera",
# "flowers - flores",
# "chocolate - chocolate",
# "mug - taza",
# "photo album - album de fotos",
# "car - auto",
# "gift basket - canasta de regalos",
# "money - dinero",
# "thank you so much - muchas gracias",
# "thank you very much - muchas gracias",
# "thank you - gracias",
# "thanks a lot - muchas gracias",
# "thanks - gracias",
# "thanks a bunch - gracias un montón",
# "not at all - para nada",
# "you're welcome - de nada",
# "my pleasure - mi placer",
# "sure, no problem - seguro, ningún problema",
# "you bet - por supuesto",
# "anytime - cuando quieras",
# "desk - escritorio",
# "calculator - calculadora",
# "eraser - borrador",
# "folder - folder",
# "glue sticks - goma en barra",
# "marker - plumón",
# "ruler - regla",
# "scissors - tijeras",
# "sticky note - pósit",
# "stapler - engrapadora",
# "paper - papel",
# "paper punch - perforadora de papel",
# "highlighter - resaltador",
# "sharpener - tajador",
# "colored pencils - lapices de colores",
# "crayons - crayones",
# "quiz - prueba",
# "dish - plato",
# "tomato - tomate",
# "races - carreras",
# "busses - autobuses",
# "boxes - cajas",
# "prizes - premios",
# "kisses - besos",
# "watches - relojes",
# "lamps - lamparas",
# "roof - techo",
# "graph - grafico",
# "laughs - risas",
# "crabs - cangrejos",
# "gloves - guantes",
